# %%
install.packages('igraph')
install.packages('Matrix')
install.packages('pracma')

# %%
library('igraph')
library('Matrix')
library('pracma')

# %% [markdown]
# ## Part1_1 Structural properties of the Facebook network

# %% [markdown]
# ### 1_1 Question 1

# %%
g<-read_graph('./facebook_combined/facebook_combined.txt', format = 'edgelist', directed=F)

# %%
summary(g)

# %%
is_connected(g)

# %% [markdown]
# ### 1_1 Question 2

# %%
diameter(g)

# %% [markdown]
# ### 1_1 Question 3

# %%
d <- degree_distribution(g)
plot((1:length(d))-1, d, type='l', col=colors()[32],lwd = 4)

# %% [markdown]
# ### 1_1 Question 4

# %%
d <- degree_distribution(g)
x <- 1:length(d)-1
y <- d
plot(x, y, log = 'xy', type='l', col=colors()[32],lwd = 4)

# %%
x1 <- log10(x[y>0])
y1 <- log10(y[y>0])
lm(y1~x1)

# %% [markdown]
# ## Part1_2 Personalized network

# %% [markdown]
# ### 1_2 Question 5

# %%
eg <- make_ego_graph(g, order=1, nodes=1, mode="all")
eg

# %% [markdown]
# ### 1_2 Question 6

# %%
diameter(eg[[1]])

# %% [markdown]
# ### 1_2 Question 7___no code

# %% [markdown]
# ## Part1_3 Core node’s personalized network

# %% [markdown]
# ### 1_3 Question 8

# %%
id <- degree(g, v=V(g)) >= 200
nodes <- V(g)[id]
length(nodes)

# %%
mean(degree(g, v=nodes))

# %% [markdown]
# ### 1_3 Question 9

# %%
nodes_pool <- c(1, 108, 349, 484, 1087)

# %%
node <- nodes_pool[1]
eg <- make_ego_graph(g, order=1, nodes=node, mode="all")[[1]]
eg_coords <- layout_with_fr(eg)
ed_no_edges <- delete_edges(eg, E(eg))

eg_com1 <- cluster_fast_greedy(eg)
plot(eg, vertex.size=3, vertex.label=NA, vertex.color=membership(eg_com1), 
     layout=eg_coords, main=paste(node,':cluster_fast_greedy'))
print(modularity(eg_com1))


eg_com2 <- cluster_edge_betweenness(eg)
plot(eg,vertex.size=3, vertex.label=NA, 
     vertex.color=membership(eg_com2), 
     layout=eg_coords, main=paste(node,':cluster_edge_betweenness'))
print(modularity(eg_com2))

eg_com3 <- cluster_infomap(eg)
plot(eg,vertex.size=3, vertex.label=NA, 
     vertex.color=membership(eg_com3), 
     layout=eg_coords, main=paste(node,':cluster_infomap'))
print(modularity(eg_com3))
# Out:
# [1] 0.4131014
# Plot with title "1 :cluster_fast_greedy"
# [1] 0.3533022
# Plot with title "1 :cluster_edge_betweenness"
# [1] 0.3891185
# Plot with title "1 :cluster_infomap"

# %%
node <- nodes_pool[2]
eg <- make_ego_graph(g, order=1, nodes=node, mode="all")[[1]]
eg_coords <- layout_with_fr(eg)
ed_no_edges <- delete_edges(eg, E(eg))

eg_com1 <- cluster_fast_greedy(eg)
plot(ed_no_edges, vertex.size=3, vertex.label=NA, vertex.color=membership(eg_com1), 
     layout=eg_coords, main=paste(node,':cluster_fast_greedy'))
print(modularity(eg_com1))


eg_com2 <- cluster_edge_betweenness(eg)
plot(ed_no_edges,vertex.size=3, vertex.label=NA, 
     vertex.color=membership(eg_com2), 
     layout=eg_coords, main=paste(node,':cluster_edge_betweenness'))
print(modularity(eg_com2))

eg_com3 <- cluster_infomap(eg)
plot(ed_no_edges,vertex.size=3, vertex.label=NA, 
     vertex.color=membership(eg_com3), 
     layout=eg_coords, main=paste(node,':cluster_infomap'))
print(modularity(eg_com3))
# Out:
# [1] 0.4359294

# %%
node <- nodes_pool[3]
eg <- make_ego_graph(g, order=1, nodes=node, mode="all")[[1]]
eg_coords <- layout_with_fr(eg)
ed_no_edges <- delete_edges(eg, E(eg))

eg_com1 <- cluster_fast_greedy(eg)
plot(ed_no_edges, vertex.size=3, vertex.label=NA, vertex.color=membership(eg_com1), 
     layout=eg_coords, main=paste(node,':cluster_fast_greedy'))
print(modularity(eg_com1))


eg_com2 <- cluster_edge_betweenness(eg)
plot(ed_no_edges,vertex.size=3, vertex.label=NA, 
     vertex.color=membership(eg_com2), 
     layout=eg_coords, main=paste(node,':cluster_edge_betweenness'))
print(modularity(eg_com2))

eg_com3 <- cluster_infomap(eg)
plot(ed_no_edges,vertex.size=3, vertex.label=NA, 
     vertex.color=membership(eg_com3), 
     layout=eg_coords, main=paste(node,':cluster_infomap'))
print(modularity(eg_com3))
# Out:
# [1] 0.2517149
# Plot with title "349 :cluster_fast_greedy"
# [1] 0.3533022
# Plot with title "349 :cluster_edge_betweenness"
# [1] 0.3941254
# Plot with title "349 :cluster_infomap"

# %%
node <- nodes_pool[4]
eg <- make_ego_graph(g, order=1, nodes=node, mode="all")[[1]]
eg_coords <- layout_with_fr(eg)
ed_no_edges <- delete_edges(eg, E(eg))

eg_com1 <- cluster_fast_greedy(eg)
plot(ed_no_edges, vertex.size=3, vertex.label=NA, vertex.color=membership(eg_com1), 
     layout=eg_coords, main=paste(node,':cluster_fast_greedy'))
print(modularity(eg_com1))


eg_com2 <- cluster_edge_betweenness(eg)
plot(ed_no_edges,vertex.size=3, vertex.label=NA, 
     vertex.color=membership(eg_com2), 
     layout=eg_coords, main=paste(node,':cluster_edge_betweenness'))
print(modularity(eg_com2))

eg_com3 <- cluster_infomap(eg)
plot(ed_no_edges,vertex.size=3, vertex.label=NA, 
     vertex.color=membership(eg_com3), 
     layout=eg_coords, main=paste(node,':cluster_infomap'))
print(modularity(eg_com3))
# Out:
# [1] 0.5070016
# Plot with title "484 :cluster_fast_greedy"
# [1] 0.3533022
# Plot with title "484 :cluster_edge_betweenness"
# [1] 0.3941254
# Plot with title "484 :cluster_infomap"

# %%
node <- nodes_pool[5]
eg <- make_ego_graph(g, order=1, nodes=node, mode="all")[[1]]
eg_coords <- layout_with_fr(eg)
ed_no_edges <- delete_edges(eg, E(eg))

eg_com1 <- cluster_fast_greedy(eg)
plot(ed_no_edges, vertex.size=3, vertex.label=NA, vertex.color=membership(eg_com1), 
     layout=eg_coords, main=paste(node,':cluster_fast_greedy'))
print(modularity(eg_com1))


eg_com2 <- cluster_edge_betweenness(eg)
plot(ed_no_edges,vertex.size=3, vertex.label=NA, 
     vertex.color=membership(eg_com2), 
     layout=eg_coords, main=paste(node,':cluster_edge_betweenness'))
print(modularity(eg_com2))

eg_com3 <- cluster_infomap(eg)
plot(ed_no_edges,vertex.size=3, vertex.label=NA, 
     vertex.color=membership(eg_com3), 
     layout=eg_coords, main=paste(node,':cluster_infomap'))
print(modularity(eg_com3))
# Out:
# [1] 0.1455315
# Plot with title "1087 :cluster_fast_greedy"
# [1] 0.3533022
# Plot with title "1087 :cluster_edge_betweenness"
# [1] 0.3941254
# Plot with title "1087 :cluster_infomap"
